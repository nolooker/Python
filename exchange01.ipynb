# %%
import pandas as pd
import requests

# %%
dataInFolder = './../data/'

# %%
authkey = 'sfpGwEhbWejlYf8aFoPZzO65UKSGXmMu'
searchdate = '20230406'
data = 'AP01'

url = 'https://www.koreaexim.go.kr/site/program/financial/exchangeJSON?authkey={}&data={}'.format(authkey, data)

response = requests.get(url)
r_data = response.json()
exchange = pd.DataFrame(r_data)
exchange
# Out:
#     result  cur_unit       ttb       tts deal_bas_r   bkpr yy_efee_r  \
# 0        1       AED     353.6    360.75     357.18    357         0
# 1        1       AUD    873.29    890.94     882.12    882         0
# 2        1       BHD  3,444.76  3,514.35   3,479.56  3,479         0
# 3        1       BND    977.88    997.63     987.76    987         0
# 4        1       CAD    965.63    985.14     975.39    975         0
# 5        1       CHF  1,433.13  1,462.08   1,447.61  1,447         0
# 6        1       CNH    189.08    192.89     190.99    190         0
# 7        1       DKK    190.16    194.01     192.09    192         0
# 8        1       EUR   1,416.9  1,445.53   1,431.22  1,431         0
# 9        1       GBP  1,618.92  1,651.63   1,635.28  1,635         0
# 10       1       HKD    165.45     168.8     167.13    167         0
# 11       1  IDR(100)       8.7      8.87       8.79      8         0
# 12       1  JPY(100)    991.32  1,011.35   1,001.34  1,001         0
# ...

# %%
exchange = pd.DataFrame()
exchange
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
#https://www.koreaexim.go.kr/site/program/financial/exchangeJSON?authkey=sfpGwEhbWejlYf8aFoPZzO65UKSGXmMu&searchdate=20180102&data=AP01

# %%
authkey = 'sfpGwEhbWejlYf8aFoPZzO65UKSGXmMu'
searchdate = '20230406'
data = 'AP01'

url = 'https://www.koreaexim.go.kr/site/program/financial/exchangeJSON?authkey={}&searchdate={}&data={}'.format(authkey, searchdate, data)

response = requests.get(url)
r_data = response.json()
exchange = pd.DataFrame(r_data)
exchange
# Out:
#     result  cur_unit       ttb       tts deal_bas_r   bkpr yy_efee_r  \
# 0        1       AED     353.6    360.75     357.18    357         0
# 1        1       AUD    873.29    890.94     882.12    882         0
# 2        1       BHD  3,444.76  3,514.35   3,479.56  3,479         0
# 3        1       BND    977.88    997.63     987.76    987         0
# 4        1       CAD    965.63    985.14     975.39    975         0
# 5        1       CHF  1,433.13  1,462.08   1,447.61  1,447         0
# 6        1       CNH    189.08    192.89     190.99    190         0
# 7        1       DKK    190.16    194.01     192.09    192         0
# 8        1       EUR   1,416.9  1,445.53   1,431.22  1,431         0
# 9        1       GBP  1,618.92  1,651.63   1,635.28  1,635         0
# 10       1       HKD    165.45     168.8     167.13    167         0
# 11       1  IDR(100)       8.7      8.87       8.79      8         0
# 12       1  JPY(100)    991.32  1,011.35   1,001.34  1,001         0
# ...

# %%
# 컬럼 정보
#result 조회 결과
#'CUR_UNIT':'통화코드',
#'CUR_NM':'국가/통화명',
#'TTB':'전신환(송금)받으실때',
#'TTS':'전신환(송금)보내실때',
#'DEAL_BAS_R':'매매 기준율',
#'BKPR':'장부가격',
#'YY_EFEE_R':'년환가료율',
#'TEN_DD_EFEE_R':'10일환가료율',
#'KFTC_DEAL_BAS_R':'서울외국환중개 매매기준율',
#'KFTC_BKPR':'서울외국환중개 장부가격'

# %%
exchange.columns
# Out:
# Index(['result', 'cur_unit', 'ttb', 'tts', 'deal_bas_r', 'bkpr', 'yy_efee_r',
#        'ten_dd_efee_r', 'kftc_bkpr', 'kftc_deal_bas_r', 'cur_nm'],
#       dtype='object')

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 money = pd.read_json(dataInFolder + 'exchage_money.json')
#       2 money
#
# File C:\Python311\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File C:\Python311\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
column_dict = {'CUR_UNIT':'통화코드',
                'CUR_NM':'국가/통화명',
                'TTB':'전신환(송금)받으실때',
                'TTS':'전신환(송금)보내실때',
                'DEAL_BAS_R':'매매 기준율',
                'BKPR':'장부가격',
                'YY_EFEE_R':'년환가료율',
                'TEN_DD_EFEE_R':'10일환가료율',
                'KFTC_DEAL_BAS_R':'서울외국환중개 매매기준율',
                'KFTC_BKPR':'서울외국환중개 장부가격'}

exchange = exchange(columns=column_dict)
exchange
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 12
#       1 column_dict = {'CUR_UNIT':'통화코드',
#       2                 'CUR_NM':'국가/통화명',
#       3                 'TTB':'전신환(송금)받으실때',
#    (...)
#       9                 'KFTC_DEAL_BAS_R':'서울외국환중개 매매기준율',
#      10                 'KFTC_BKPR':'서울외국환중개 장부가격'}
# ---> 12 exchange = exchange(columns=column_dict)
#      13 exchange
#
# TypeError: 'DataFrame' object is not callable
