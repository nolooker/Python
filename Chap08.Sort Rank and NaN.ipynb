# %% [markdown]
# <h1>정렬&순위 그리고 누락값</h1>

# %% [markdown]
# <h3><font color='orange'>데이터 정렬하기</h3>

# %% [markdown]
# <h3><font color='pink'>데이터 프레임 읽기</h3>

# %%
import pandas as pd

# %%
payment = pd.read_csv('./../data/payment01.csv', encoding='cp949', index_col='사원명')
display(payment)
# Out:
#      출장지역  출장기간   부서  성별     교통비   식비
# 사원명
# 강감찬    서울   3.0  영업부  남자  1000.0  500
# 김구     서울   NaN  총무부  남자  2000.0  300
# 김유신    부산   7.0  전산부  남자  3000.0  600
# 신사임당   부산   5.0  영업부  여자     NaN  200
# 선덕여왕   서울   6.0  총무부  여자  4000.0  800

# %% [markdown]
# <h3><font color='pink'>출장 기간 열을 Series로 추출</h3>

# %%
period = payment['출장기간']
print(period)
# Out:
# 사원명
# 강감찬     3.0
# 김구      NaN
# 김유신     7.0
# 신사임당    5.0
# 선덕여왕    6.0
# Name: 출장기간, dtype: float64

# %% [markdown]
# <h3><font color='pink'>색인을 이용한 정렬</h3>

# %%
result = period.sort_index()
print(result)
# Out:
# 사원명
# 강감찬     3.0
# 김구      NaN
# 김유신     7.0
# 선덕여왕    6.0
# 신사임당    5.0
# Name: 출장기간, dtype: float64

# %%
result = period.sort_index(ascending=False)
print(result)
# Out:
# 사원명
# 신사임당    5.0
# 선덕여왕    6.0
# 김유신     7.0
# 김구      NaN
# 강감찬     3.0
# Name: 출장기간, dtype: float64

# %% [markdown]
# <h3><font color='pink'>값을 이용한 정렬</h3>

# %%
result = period.sort_values()
result
# Out:
# 사원명
# 강감찬     3.0
# 신사임당    5.0
# 선덕여왕    6.0
# 김유신     7.0
# 김구      NaN
# Name: 출장기간, dtype: float64

# %%
result = period.sort_values(ascending=False)
result
# Out:
# 사원명
# 김유신     7.0
# 선덕여왕    6.0
# 신사임당    5.0
# 강감찬     3.0
# 김구      NaN
# Name: 출장기간, dtype: float64

# %%
result = period.sort_values(ascending=True)
result
# Out:
# 사원명
# 강감찬     3.0
# 신사임당    5.0
# 선덕여왕    6.0
# 김유신     7.0
# 김구      NaN
# Name: 출장기간, dtype: float64

# %% [markdown]
# <h3><font color='orange'>axis 옵션을 이용한 DataFrame 정렬하기</h3>

# %% [markdown]
# <h3><font color='pink'>오름차순 정렬</h3>

# %%
result = payment.sort_index(axis = 0)
result
# Out:
#      출장지역  출장기간   부서  성별     교통비   식비
# 사원명
# 강감찬    서울   3.0  영업부  남자  1000.0  500
# 김구     서울   NaN  총무부  남자  2000.0  300
# 김유신    부산   7.0  전산부  남자  3000.0  600
# 선덕여왕   서울   6.0  총무부  여자  4000.0  800
# 신사임당   부산   5.0  영업부  여자     NaN  200

# %%
result = payment.sort_index(axis = 1)
result
# Out:
#          교통비   부서  성별   식비  출장기간 출장지역
# 사원명
# 강감찬   1000.0  영업부  남자  500   3.0   서울
# 김구    2000.0  총무부  남자  300   NaN   서울
# 김유신   3000.0  전산부  남자  600   7.0   부산
# 신사임당     NaN  영업부  여자  200   5.0   부산
# 선덕여왕  4000.0  총무부  여자  800   6.0   서울

# %% [markdown]
# <h3><font color='pink'>내림차순 정렬</h3>

# %%
result = payment.sort_index(axis=1, ascending=False)
result
# Out:
#      출장지역  출장기간   식비  성별   부서     교통비
# 사원명
# 강감찬    서울   3.0  500  남자  영업부  1000.0
# 김구     서울   NaN  300  남자  총무부  2000.0
# 김유신    부산   7.0  600  남자  전산부  3000.0
# 신사임당   부산   5.0  200  여자  영업부     NaN
# 선덕여왕   서울   6.0  800  여자  총무부  4000.0

# %% [markdown]
# <h3><font color='orange'>값을 이용한 DataFrame 정렬하기</h3>

# %% [markdown]
# <h3><font color='pink'>by 매개 변수 사용</h3>

# %%
result = payment.sort_values(by=['교통비'])
result
# Out:
#      출장지역  출장기간   부서  성별     교통비   식비
# 사원명
# 강감찬    서울   3.0  영업부  남자  1000.0  500
# 김구     서울   NaN  총무부  남자  2000.0  300
# 김유신    부산   7.0  전산부  남자  3000.0  600
# 선덕여왕   서울   6.0  총무부  여자  4000.0  800
# 신사임당   부산   5.0  영업부  여자     NaN  200

# %% [markdown]
# <h3><font color='pink'>ascending 매개 변수 사용</h3>

# %%
result = payment.sort_values(by=['교통비'], ascending=False)
result
# Out:
#      출장지역  출장기간   부서  성별     교통비   식비
# 사원명
# 선덕여왕   서울   6.0  총무부  여자  4000.0  800
# 김유신    부산   7.0  전산부  남자  3000.0  600
# 김구     서울   NaN  총무부  남자  2000.0  300
# 강감찬    서울   3.0  영업부  남자  1000.0  500
# 신사임당   부산   5.0  영업부  여자     NaN  200

# %% [markdown]
# <h3><font color='pink'>여러 개의 컬럼 명시하기</h3>

# %%
result = payment.sort_values(by=['출장지역','교통비'], ascending=[True,False])
result
# Out:
#      출장지역  출장기간   부서  성별     교통비   식비
# 사원명
# 김유신    부산   7.0  전산부  남자  3000.0  600
# 신사임당   부산   5.0  영업부  여자     NaN  200
# 선덕여왕   서울   6.0  총무부  여자  4000.0  800
# 김구     서울   NaN  총무부  남자  2000.0  300
# 강감찬    서울   3.0  영업부  남자  1000.0  500

# %% [markdown]
# <h1>순위 매기기</h1>

# %% [markdown]
# <h3><font color='orange'>일부 데이터 변경하기</h3>

# %%
payment.loc[['김구'],['출장기간']]=5.0
payment.loc[['신사임당'],['교통비']]=3000.0
payment
# Out:
#      출장지역  출장기간   부서  성별     교통비   식비
# 사원명
# 강감찬    서울   3.0  영업부  남자  1000.0  500
# 김구     서울   5.0  총무부  남자  2000.0  300
# 김유신    부산   7.0  전산부  남자  3000.0  600
# 신사임당   부산   5.0  영업부  여자  3000.0  200
# 선덕여왕   서울   6.0  총무부  여자  4000.0  800

# %%
period = payment['출장기간']
period.to_frame()
# Out:
#       출장기간
# 사원명
# 강감찬    3.0
# 김구     5.0
# 김유신    7.0
# 신사임당   5.0
# 선덕여왕   6.0

# %% [markdown]
# <h3><font color='pink'>데이터 프레임의 랭킹</h3>

# %%
period.rank()
# Out:
# 사원명
# 강감찬     1.0
# 김구      2.5
# 김유신     5.0
# 신사임당    2.5
# 선덕여왕    4.0
# Name: 출장기간, dtype: float64

# %%
period.rank(method='first')
# Out:
# 사원명
# 강감찬     1.0
# 김구      2.0
# 김유신     5.0
# 신사임당    3.0
# 선덕여왕    4.0
# Name: 출장기간, dtype: float64

# %%
period.rank(method='min')
# Out:
# 사원명
# 강감찬     1.0
# 김구      2.0
# 김유신     5.0
# 신사임당    2.0
# 선덕여왕    4.0
# Name: 출장기간, dtype: float64

# %%
period.rank(method='max')
# Out:
# 사원명
# 강감찬     1.0
# 김구      3.0
# 김유신     5.0
# 신사임당    3.0
# 선덕여왕    4.0
# Name: 출장기간, dtype: float64

# %% [markdown]
# <h3><font color='pink'>ascending 매개 변수 사용</h3>

# %%
minval = period.rank(ascending = False, method='min')
minval
# Out:
# 사원명
# 강감찬     5.0
# 김구      3.0
# 김유신     1.0
# 신사임당    3.0
# 선덕여왕    2.0
# Name: 출장기간, dtype: float64

# %%
minval = period.rank(ascending = True, method='min')
minval
# Out:
# 사원명
# 강감찬     1.0
# 김구      2.0
# 김유신     5.0
# 신사임당    2.0
# 선덕여왕    4.0
# Name: 출장기간, dtype: float64

# %%
payment['rank'] = minval
payment
# Out:
#      출장지역  출장기간   부서  성별     교통비   식비  rank
# 사원명
# 강감찬    서울   3.0  영업부  남자  1000.0  500   1.0
# 김구     서울   5.0  총무부  남자  2000.0  300   2.0
# 김유신    부산   7.0  전산부  남자  3000.0  600   5.0
# 신사임당   부산   5.0  영업부  여자  3000.0  200   2.0
# 선덕여왕   서울   6.0  총무부  여자  4000.0  800   4.0

# %%
payment.rank(axis=1, ascending=False)
# Out:
# C:\Users\kosmo\AppData\Local\Temp\ipykernel_7224\2585736250.py:1: FutureWarning: Dropping of nuisance columns in DataFrame.rank is deprecated; in a future version this will raise TypeError. Select only valid columns before calling rank.
#   payment.rank(axis=1, ascending=False)
#       출장기간  교통비   식비  rank
# 사원명
# 강감찬    3.0  1.0  2.0   4.0
# 김구     3.0  1.0  2.0   4.0
# 김유신    3.0  1.0  2.0   4.0
# 신사임당   3.0  1.0  2.0   4.0
# 선덕여왕   3.0  1.0  2.0   4.0

# %%
다음 코드를 사용하여 데이터 프레임을 생성해 주세요.
모든 데이터는 head()메소드를 사용하여 출력하도록 합니다.

homeware = pd.read_csv('./../data/가전제품.csv', encoding='cp949')
rowindex = homeware['제품명'] + '_' + homeware['분기'].astype('str') + '사분기'
homeware.index = rowindex
homeware.head()

'일생산량' 열을 Series로 추출하고, 다음 물음에 답해 주세요.
   행 색인을 기반으로 오름차순, 내림차순으로 정렬해 보세요.
   '일생산량'이 가장 적은 행을 추출해 보세요.
   '일생산량'이 가장 많은 행을 추출해 보세요.
   
homeware에 대하여, 다음 물음에 답해 주세요.
   행 색인을 기반으로 행을 추출해 보세요.
   컬럼 이름을 오름차순, 내림차순으로 정렬해 보세요.
   '총생산량'이 가장 적은 행을 추출해 보세요.
   '불량품'이 가장 많은 행을 추출해 보세요.
   '생산일수'이 가장 적은 순으로, 일생산량이 많은 순으로 행을 추출해 보세요.

# %%
import pandas as pd

# %%
homeware = pd.read_csv('./../data/가전제품.csv', encoding='cp949')

# %%
homeware
# Out:
#       제품명  분기  일생산량  생산일수   총생산량  불량품  출고량
# 0    미니오븐   1    85    20   6000   24   50
# 1    전기밥솥   1    85    25   9000   36   80
# 2     믹서기   1    90    25  12000   48   80
# 3   전자레인지   1    85    25   7200   29   50
# 4   미니냉장고   1    65    25   4800   19   65
# 5     선풍기   1    70    25  10800   43   55
# 6    미니오븐   2    85    20   4960   26   55
# 7    전기밥솥   2    70    20  11160   39   65
# 8     믹서기   2    85    25  12800   39   80
# 9   전자레인지   2    90    20   7680   22   60
# 10  미니냉장고   2    90    25   5120   22   60
# 11    선풍기   2    65    20  11520   33   60
# 12   미니오븐   3    95    20   6200   31   65
# 13   전기밥솥   3    90    25   9300   52   90
# 14    믹서기   3    80    20  12400   43   95
# 15  전자레인지   3    70    25   7440   26   50
# 16  미니냉장고   3    90    25  12400   17   75
# 17    선풍기   3    90    25   7440   21   50
# 18   미니오븐   4    80    25   6200   47   80
# 19   전기밥솥   4   100    25   9300   33   50
# 20    믹서기   4    80    25   6400   43   95
# ...

# %%
rowindex = homeware['제품명'] + '_' + homeware['분기'].astype('str') + '사분기'
homeware.index = rowindex
homeware.head()
# Out:
#               제품명  분기  일생산량  생산일수   총생산량  불량품  출고량
# 미니오븐_1사분기    미니오븐   1    85    20   6000   24   50
# 전기밥솥_1사분기    전기밥솥   1    85    25   9000   36   80
# 믹서기_1사분기      믹서기   1    90    25  12000   48   80
# 전자레인지_1사분기  전자레인지   1    85    25   7200   29   50
# 미니냉장고_1사분기  미니냉장고   1    65    25   4800   19   65

# %%
work = homeware['일생산량']
work.to_frame()
# Out:
#             일생산량
# 미니오븐_1사분기     85
# 전기밥솥_1사분기     85
# 믹서기_1사분기      90
# 전자레인지_1사분기    85
# 미니냉장고_1사분기    65
# 선풍기_1사분기      70
# 미니오븐_2사분기     85
# 전기밥솥_2사분기     70
# 믹서기_2사분기      85
# 전자레인지_2사분기    90
# 미니냉장고_2사분기    90
# 선풍기_2사분기      65
# 미니오븐_3사분기     95
# 전기밥솥_3사분기     90
# 믹서기_3사분기      80
# 전자레인지_3사분기    70
# 미니냉장고_3사분기    90
# 선풍기_3사분기      90
# 미니오븐_4사분기     80
# 전기밥솥_4사분기    100
# 믹서기_4사분기      80
# 전자레인지_4사분기    95
# 미니냉장고_4사분기    85
# 선풍기_4사분기      70

# %% [markdown]
# <h1>누락된 테이터 제거</h1>

# %% [markdown]
# <h3><font color='orange'>데이터 프레임 읽기</h3>

# %%
import numpy as np
import pandas as pd

# %%
payment = pd.read_csv('./../data/payment01.csv', encoding='cp949', index_col='사원명')
payment
# Out:
#      출장지역  출장기간   부서  성별     교통비   식비
# 사원명
# 강감찬    서울   3.0  영업부  남자  1000.0  500
# 김구     서울   NaN  총무부  남자  2000.0  300
# 김유신    부산   7.0  전산부  남자  3000.0  600
# 신사임당   부산   5.0  영업부  여자     NaN  200
# 선덕여왕   서울   6.0  총무부  여자  4000.0  800

# %% [markdown]
# <h3><font color='pink'>누락된 값 체크하기</h3>

# %%
display(payment.isnull())
# Out:
#        출장지역   출장기간     부서     성별    교통비     식비
# 사원명
# 강감찬   False  False  False  False  False  False
# 김구    False   True  False  False  False  False
# 김유신   False  False  False  False  False  False
# 신사임당  False  False  False  False   True  False
# 선덕여왕  False  False  False  False  False  False

# %%
display(payment.notnull())
# Out:
#       출장지역   출장기간    부서    성별    교통비    식비
# 사원명
# 강감찬   True   True  True  True   True  True
# 김구    True  False  True  True   True  True
# 김유신   True   True  True  True   True  True
# 신사임당  True   True  True  True  False  True
# 선덕여왕  True   True  True  True   True  True

# %% [markdown]
# <h3><font color='pink'>행 단위로 누락된 값 제거</h3>

# %%
result = payment.dropna(axis=0)
result
# Out:
#      출장지역  출장기간   부서  성별     교통비   식비
# 사원명
# 강감찬    서울   3.0  영업부  남자  1000.0  500
# 김유신    부산   7.0  전산부  남자  3000.0  600
# 선덕여왕   서울   6.0  총무부  여자  4000.0  800

# %%
result = payment.dropna(axis=0, how='all')
result
# Out:
#      출장지역  출장기간   부서  성별     교통비   식비
# 사원명
# 강감찬    서울   3.0  영업부  남자  1000.0  500
# 김구     서울   NaN  총무부  남자  2000.0  300
# 김유신    부산   7.0  전산부  남자  3000.0  600
# 신사임당   부산   5.0  영업부  여자     NaN  200
# 선덕여왕   서울   6.0  총무부  여자  4000.0  800

# %%
result = payment.dropna(subset=['출장기간'])
result
# Out:
#      출장지역  출장기간   부서  성별     교통비   식비
# 사원명
# 강감찬    서울   3.0  영업부  남자  1000.0  500
# 김유신    부산   7.0  전산부  남자  3000.0  600
# 신사임당   부산   5.0  영업부  여자     NaN  200
# 선덕여왕   서울   6.0  총무부  여자  4000.0  800

# %% [markdown]
# <h3><font color='pink'>열 단위로 누락된 값 제거</h3>

# %%
result = payment.dropna(axis=1)
result
# Out:
#      출장지역   부서  성별   식비
# 사원명
# 강감찬    서울  영업부  남자  500
# 김구     서울  총무부  남자  300
# 김유신    부산  전산부  남자  600
# 신사임당   부산  영업부  여자  200
# 선덕여왕   서울  총무부  여자  800

# %% [markdown]
# <h1>누락된 테이터 치환</h1>

# %% [markdown]
# <h3><font color='orange'>데이터 프레임 읽기</h3>

# %%
payment = pd.read_csv('./../data/payment01.csv', encoding='cp949', index_col='사원명')
payment
# Out:
#      출장지역  출장기간   부서  성별     교통비   식비
# 사원명
# 강감찬    서울   3.0  영업부  남자  1000.0  500
# 김구     서울   NaN  총무부  남자  2000.0  300
# 김유신    부산   7.0  전산부  남자  3000.0  600
# 신사임당   부산   5.0  영업부  여자     NaN  200
# 선덕여왕   서울   6.0  총무부  여자  4000.0  800

# %% [markdown]
# <h3><font color='pink'>스칼라 값을 이용한 누락된 값 제거</h3>

# %%
result = payment.fillna(value=0, inplace=False)
result
# Out:
#      출장지역  출장기간   부서  성별     교통비   식비
# 사원명
# 강감찬    서울   3.0  영업부  남자  1000.0  500
# 김구     서울   0.0  총무부  남자  2000.0  300
# 김유신    부산   7.0  전산부  남자  3000.0  600
# 신사임당   부산   5.0  영업부  여자     0.0  200
# 선덕여왕   서울   6.0  총무부  여자  4000.0  800

# %%
payment
# Out:
#      출장지역  출장기간   부서  성별     교통비   식비
# 사원명
# 강감찬    서울   3.0  영업부  남자  1000.0  500
# 김구     서울   NaN  총무부  남자  2000.0  300
# 김유신    부산   7.0  전산부  남자  3000.0  600
# 신사임당   부산   5.0  영업부  여자     NaN  200
# 선덕여왕   서울   6.0  총무부  여자  4000.0  800

# %%
payment.fillna(value=0, inplace=True)
payment
# Out:
#      출장지역  출장기간   부서  성별     교통비   식비
# 사원명
# 강감찬    서울   3.0  영업부  남자  1000.0  500
# 김구     서울   0.0  총무부  남자  2000.0  300
# 김유신    부산   7.0  전산부  남자  3000.0  600
# 신사임당   부산   5.0  영업부  여자     0.0  200
# 선덕여왕   서울   6.0  총무부  여자  4000.0  800

# %%
payment
# Out:
#      출장지역  출장기간   부서  성별     교통비   식비
# 사원명
# 강감찬    서울   3.0  영업부  남자  1000.0  500
# 김구     서울   0.0  총무부  남자  2000.0  300
# 김유신    부산   7.0  전산부  남자  3000.0  600
# 신사임당   부산   5.0  영업부  여자     0.0  200
# 선덕여왕   서울   6.0  총무부  여자  4000.0  800

# %% [markdown]
# <h3><font color='pink'>사전을 이용한 누락 값 치환</h3>

# %%
payment.loc[['강감찬', '김유신'],['출장기간','성별']] = np.nan
payment.loc[['신사임당', '선덕여왕'],['식비']] = np.nan
payment
# Out:
#      출장지역  출장기간   부서   성별     교통비     식비
# 사원명
# 강감찬    서울   NaN  영업부  NaN  1000.0  500.0
# 김구     서울   0.0  총무부   남자  2000.0  300.0
# 김유신    부산   NaN  전산부  NaN  3000.0  600.0
# 신사임당   부산   NaN  영업부   여자     NaN    NaN
# 선덕여왕   서울   6.0  총무부   여자  4000.0    NaN

# %%
mydict = {'출장기간':10.0, '성별':'남자', '식비':500.0}
payment.fillna(mydict, inplace=True)
payment
# Out:
#      출장지역  출장기간   부서  성별     교통비     식비
# 사원명
# 강감찬    서울  10.0  영업부  남자  1000.0  500.0
# 김구     서울   0.0  총무부  남자  2000.0  300.0
# 김유신    부산  10.0  전산부  남자  3000.0  600.0
# 신사임당   부산  10.0  영업부  여자     NaN  500.0
# 선덕여왕   서울   6.0  총무부  여자  4000.0  500.0

# %%
payment.loc[['신사임당'],['출장기간']] = np.nan
payment.loc[['신사임당'],['교통비']] = np.nan
payment.loc[['선덕여왕'],['식비']] = np.nan
payment
# Out:
#      출장지역  출장기간   부서  성별     교통비     식비
# 사원명
# 강감찬    서울  10.0  영업부  남자  1000.0  500.0
# 김구     서울   0.0  총무부  남자  2000.0  300.0
# 김유신    부산  10.0  전산부  남자  3000.0  600.0
# 신사임당   부산   NaN  영업부  여자     NaN  500.0
# 선덕여왕   서울   6.0  총무부  여자  4000.0    NaN

# %%
mydict = {'출장기간':payment['출장기간'].mean(),
          '교통비':payment['교통비'].mean(),
          '식비':payment['식비'].mean()
         }
payment.fillna(mydict, inplace=True)
payment
# Out:
#      출장지역  출장기간   부서  성별     교통비     식비
# 사원명
# 강감찬    서울  10.0  영업부  남자  1000.0  500.0
# 김구     서울   0.0  총무부  남자  2000.0  300.0
# 김유신    부산  10.0  전산부  남자  3000.0  600.0
# 신사임당   부산   6.5  영업부  여자  2500.0  500.0
# 선덕여왕   서울   6.0  총무부  여자  4000.0  475.0

# %% [markdown]
# <h1>수평 막대 그래프 그리기</h1>

# %% [markdown]
# <h3><font color='orange'>데이터 가공</h3>

# %%
chartdata01 = payment['식비'].sort_index(ascending=False)
chartdata01.to_frame()
# Out:
#          식비
# 사원명
# 신사임당  500.0
# 선덕여왕  475.0
# 김유신   600.0
# 김구    300.0
# 강감찬   500.0

# %%
import matplotlib.pyplot as plt
plt.rc('font', family='Malgun Gothic')

# %%
chartdata01.plot(kind='barh', rot=0, use_index=True, grid=False,
                table=False, color=['r','g','b','y','m'])

plt.xlabel('식비')
plt.ylabel('사원명')
plt.title('식비 지급 내역 막대 그래프')
# Out:
# Text(0.5, 1.0, '식비 지급 내역 막대 그래프')

# %%
chartdata01 = payment['식비'].sort_index(ascending=True)
chartdata01.to_frame()
# Out:
#          식비
# 사원명
# 강감찬   500.0
# 김구    300.0
# 김유신   600.0
# 선덕여왕  475.0
# 신사임당  500.0

# %%
chartdata02 = payment['식비'].sort_index(ascending=False)
chartdata02.to_frame()
# Out:
#          식비
# 사원명
# 신사임당  500.0
# 선덕여왕  475.0
# 김유신   600.0
# 김구    300.0
# 강감찬   500.0

# %%
chartdata02 = payment['식비'].sort_values(ascending=True)
chartdata02.to_frame()
# Out:
#          식비
# 사원명
# 김구    300.0
# 선덕여왕  475.0
# 강감찬   500.0
# 신사임당  500.0
# 김유신   600.0

# %%
chartdata02.plot(kind='barh', rot=0, use_index=True, grid=False,
                table=False, color=['r','g','b','y','m'])

plt.xlabel('식비')
plt.ylabel('사원명')
plt.title('식비 지급 내역(오름차순 값)')
# Out:
# Text(0.5, 1.0, '식비 지급 내역(오름차순 값)')

# %%
chartdata03 = payment['식비'].sort_values(ascending=False)
chartdata03.to_frame()
# Out:
#          식비
# 사원명
# 김유신   600.0
# 강감찬   500.0
# 신사임당  500.0
# 선덕여왕  475.0
# 김구    300.0

# %%
chartdata03.plot(kind='barh', rot=0, use_index=True, grid=False,
                table=False, color=['r','g','b','y','m'])
plt.xlabel('식비')
plt.ylabel('사원명')
plt.title('식비 지급 내역(내림차순)')
# Out:
# Text(0.5, 1.0, '식비 지급 내역(내림차순)')

# %%
chartdata01.plot(kind='barh', rot=0, use_index=True, grid=False, table=False, color=['r','g','b','y','m'])
plt.xlabel('식비')
plt.ylabel('사원')
plt.title('식비 지급 내역')
# Out:
# Text(0.5, 1.0, '식비 지급 내역')

# %%
chartdata02.plot(kind='barh', rot=0, use_index=True, grid=False,
                table=False, color=['r','g','b','y','m'])

plt.xlabel('식비')
plt.ylabel('사원명')
plt.title('식비 지급 내역(오름차순 값)')
# Out:
# Text(0.5, 1.0, '식비 지급 내역(오름차순 값)')
